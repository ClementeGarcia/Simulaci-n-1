# %% [markdown]
# <a href="https://colab.research.google.com/github/ClementeGarcia/Simulaci-n-1/blob/main/Crudo(media_muestral).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Mc Crudo (Media muestral)**
#
# I = $\int_{a}^{b}g(x) = \int_{a}^{b}w(x)f(x)dx = E[w(x)] \approx \frac{1}{N}\sum_{i=1}^{N}g(x_i) $
#
#
# $w(x) = g(x)(b-a)$
#
# $f(x) = \frac{1}{b-a} ⟹ U(a,b)$

# %%
import random
import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import quad

# %%
def f(x):
      return np.sqrt(np.arctan(x))

# %%
y , v= quad(f, 0, 1)

print(y)
# Out:
# 0.6298233442079734

# %%
def crudo(n):
  suma = 0
  for i in range(n):
    x = random.random()
    suma = suma + f(x)
  return suma/n

# %%
n1=100
L=[]
for i in range(n1):
   L.append(crudo(i+1))

print(L)
# Out:
# [np.float64(0.6060626919082047), np.float64(0.638335773562604), np.float64(0.6547338982315457), np.float64(0.41795874629017976), np.float64(0.5817567448406713), np.float64(0.5715042331430548), np.float64(0.5862702241241438), np.float64(0.7892706776260511), np.float64(0.36580394370452124), np.float64(0.6329523162056064), np.float64(0.6674233351739951), np.float64(0.6662801681971248), np.float64(0.6087330030595016), np.float64(0.6508423854689831), np.float64(0.6532356455982792), np.float64(0.5764819905443699), np.float64(0.660480323391661), np.float64(0.6274590441156785), np.float64(0.6633011528723006), np.float64(0.6508323564874676), np.float64(0.6957882348775838), np.float64(0.6431781166804623), np.float64(0.6737076981096266), np.float64(0.6326209738306631), np.float64(0.5993933305954582), np.float64(0.553166313687061), np.float64(0.6212176156197865), np.float64(0.6493618216707261), np.float64(0.6727008751637918), np.float64(0.6382308888893181), np.float64(0.5757559022214723), np.flo
# ...

# %%
plt.axhline(y = y, color= "red", linestyle = "--")
plt.plot(L)
plt.ylim(0,1)
# Out:
# (0.0, 1.0)

# %%
error = abs(y - suma/n)/y

print(error)
# Out:
# 0.0007784754699456121
